# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library for running the Notebook.

# %%
# Standard library imports
from os import path

import sys

# Set the path to the root directory of this project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package import
from src.lib import Initiate_process

# %% [markdown]
# ## User project file

# %%
user_project_file = '~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json'

# %% [markdown]
# ## Import Digit Soil SEAR
#
# To run this cell you need to set:
# 1. A _project_definition_file_, and
# 2. a _job_file_, that is linked via the _project_definition_file_.

# %%
process_file = 'digit-soil_SEAR/doc/json/process_digit-soil_sear.json'

Initiate_process(user_project_file, process_file)
# Out:
# Initiating process with user project file: ~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': [{'delete': False,
#               'overwrite': False,
#               'src_path': {'ext': 'json', 'volume': '.'},
#               'translate': True,
#               'verbose': 3}],
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
# ====== Parameters from project file:
# {'process': [{'overwrite': True,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_dk_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'DK',
#                              'pilot_site': 'Foulum',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': True},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_es_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'ES',
#                              'pilot_site': 'Arkaute',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_fi_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'FI',
#                              'pilot_site': 'Jokioinen',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_gr_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'GR',
#                              'pilot_site': 'ktima-gerovassiliou',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_analysis_date': '20231201',
#                              'sample_date': '20231201',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'canopy': 'alley',
#                              'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_hr_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'HR',
#                              'pilot_site': 'Neretva',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_nl_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'NL',
#                              'pilot_site': 'Boermarke-Zeijen',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_se_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'SE',
#                              'pilot_site': 'Loennstorp',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_uk_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'UK',
#                              'pilot_site': 'Woods',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'data_src_FPN': 'digit-soil_SEAR/data/AI4SH_SEAR_wa_results.csv',
#                              'dst_FP': 'digit-soil_SEAR/database',
#                              'instrument-brand__name': 'digit-soil',
#                              'instrument-model__name': 'bob',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'WA',
#                              'pilot_site': 'Plynlimon',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'digit-soil-sear',
#                              'sample_preparation__name': 'mx',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': False}]}
# ======
#   Json process files:
#      /Users/thomasgumbricht/projects/ai4sh_sueloanalys/digit-soil_SEAR/doc/json/process_digit-soil_sear.json
#     default_parameter_D:
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': {'delete': False,
#              'overwrite': False,
#              'src_path': {'ext': 'json', 'volume': '.'},
#              'translate': True,
#              'verbose': 3},
#  'process_path': '',
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
#
#     reading jsonObj:
#     /Users/thomasgumbricht/projects/ai4sh_sueloanalys/digit-soil_SEAR/doc/json/process_digit-soil_sear.json
#
# ########### STARTING JOB ###########
#
# Command file:
#   process_digit-soil_sear.json (9 ready processes to run)
#
#     Running process nr: 0 import_ai4sh_csv (overwriting)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 process_file = 'digit-soil_SEAR/doc/json/process_digit-soil_sear.json'
# ----> 3 Initiate_process(user_project_file, process_file)
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/import_csv_data_initiate.py:52, in Initiate_process(user_project_file, process_file)
#      49     json_job_D = Structure_processes(user_default_params_D, process_file_FPN_L)
#      51     # Run the structured processes
# ---> 52     Manage_process(user_default_params_D['project_path'],json_job_D)
#      54     print ('Done')
#      56 else:
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/import_csv_data_process.py:61, in Manage_process(project_FP, json_job_D)
#      57     Import_csv_single_line(project_FP,json_job_D[job][p_nr].process_S.process)
#      59 elif sub_process_id == 'import_ai4sh_csv':
# ---> 61     Import_ai4sh_csv(project_FP,json_job_D[job][p_nr].process_S.process)
#      63 elif sub_process_id == 'import_xspectre_json_v089':
#      65     Import_xspectre_json_v089(project_FP,json_job_D[job][p_nr].process_S.process)
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/import_csv_data_process.py:184, in Import_ai4sh_csv(project_FP, process)
#     181 column_L, data_L_L = data_pack
#     183 # Loop all rows in the csv file
# --> 184 Process_ai4sh_csv(project_FP, process, column_L, data_L_L, parameter_D, unit_D, method_D, equipment_D, equipment_model_D, equipment_id_D)
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/AI4SH_4_Ai4SH.py:553, in Process_ai4sh_csv(project_FP, process, column_L, data_L_L, all_parameter_D, unit_D, method_D, equipment_D, equipment_model_D, equipment_id_D, std_row)
#     516 """
#     517 @brief Processes CSV data records and exports them to hierarchical JSON format for AI4SH in-situ data management.
#     518
#    (...)
#     548 @return None if any error occurs during processing, otherwise creates JSON files for each sample event.
#     549 """
#     551 #global position_date_F
# --> 553 coordinate_D = Coordinates_fix(project_FP,process.parameters.point_name_position_sampledate_FPN)
#     555 #position_date_FPN = "/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_point_name_position_sampledate"
#     556
#     557 #position_date_FPN = '%s_%s.csv' % (position_date_FPN, process.parameters.pilot_site.lower())
#     558
#     559 #position_date_F = open(position_date_FPN, 'w')
#     560 #position_date_F.write('pilot_country,pilot_site,sampling_log,point_id,sample_date,min_depth,max_depth,position_name,setting,latitude,longitude\n')
#     562 if process.overwrite:
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/fix_params_coords.py:157, in Coordinates_fix(project_FP, point_name_position_sampledate_FPN)
#     152     #coordinate_D[locus_date] = {'latitude': float(row[3]),
#     153     #                                    'longitude': float(row[4])}
#     155     coordinate_D[locus] = dict(zip(column_L, row))
# --> 157     coordinate_D[locus]['latitude'] = float(coordinate_D[locus]['latitude'])
#     158     coordinate_D[locus]['longitude'] = float(coordinate_D[locus]['longitude'])
#     160 return coordinate_D
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ## Import Wetlab Greece Ktima-Gerovassiliou (VELTIA lab)

# %%
process_file = 'wetlab_GR/doc/json/process_gr_wetlab.json'

# Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Agrolab wet chemistry

# %%
process_file = 'wetlab_AI4SH/doc/json/process_wetlab_AI4SH.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Bulk density and soil mositure

# %%
process_file = 'bulkdensity/doc/json/process_bulk-density_AI4SH.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Microbiometer

# %%
process_file = 'microbiometer/doc/json/process_microbiometer_ai4sh.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Infiltration

# %%
process_file = 'infiltration/doc/json/process_infiltration_ai4sh.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import eDNA

# %%
process_file = 'eDNA/doc/json/process_eDNA_ai4sh.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import aggregate stability

# %%
process_file = 'aggregates/doc/json/process_aggregates_ai4sh.json'

Initiate_process(user_project_file, process_file)
