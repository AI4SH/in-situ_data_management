# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library for running the Notebook.

# %%
# Standard library imports
from os import path

import sys

# Set the path to the root directory of this project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package import
from src.lib import Initiate_process

# %% [markdown]
# ## User project file

# %%
user_project_file = '~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json'

# %% [markdown]
# ## Import Digit Soil SEAR
#
# To run this cell you need to set:
# 1. A _project_definition_file_, and
# 2. a _job_file_, that is linked via the _project_definition_file_.

# %%
process_file = 'digit-soil_SEAR/doc/json/process_digit-soil_sear.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Wetlab Greece Ktima-Gerovassiliou (VELTIA lab)

# %%
process_file = 'wetlab_GR/doc/json/process_gr_wetlab.json'

# Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Agrolab wet chemistry

# %%
process_file = 'wetlab_AI4SH/doc/json/process_wetlab_AI4SH.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Bulk density and soil mositure

# %%
process_file = 'bulkdensity/doc/json/process_bulk-density_AI4SH.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Microbiometer

# %%
process_file = 'microbiometer/doc/json/process_microbiometer_ai4sh.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import Infiltration

# %%
process_file = 'infiltration/doc/json/process_infiltration_ai4sh.json'

Initiate_process(user_project_file, process_file)
# Out:
# Initiating process with user project file: ~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': [{'delete': False,
#               'overwrite': False,
#               'src_path': {'ext': 'json', 'volume': '.'},
#               'translate': True,
#               'verbose': 3}],
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
# ====== Parameters from project file:
# {'process': [{'overwrite': True,
#               'parameters': {'coordinates_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_point_name_position_sampledate_all.csv',
#                              'data_src_FPN': 'infiltration/data/AI4SH_infiltration_SE.csv',
#                              'dst_FP': 'infiltration/database',
#                              'instrument-brand__name': 'single-ring',
#                              'instrument-model__name': 'tin-can',
#                              'instrument_id': '0',
#                              'method_src_FPN': 'header_dictionary/header_dictionary.csv',
#                              'pilot_country': 'SE',
#                              'pilot_site': 'Loennstorp',
#                              'procedure': 'single-ring infiltration',
#                              'sample_preparation__name': 'None',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ai4sh_csv',
#               'translate': True}]}
# ======
#   Json process files:
#      /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/doc/json/process_infiltration_ai4sh.json
#     default_parameter_D:
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': {'delete': False,
#              'overwrite': False,
#              'src_path': {'ext': 'json', 'volume': '.'},
#              'translate': True,
#              'verbose': 3},
#  'process_path': '',
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
#
#     reading jsonObj:
#     /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/doc/json/process_infiltration_ai4sh.json
#
# ########### STARTING JOB ###########
#
# Command file:
#   process_infiltration_ai4sh.json (1 ready processes to run)
#
#     Running process nr: 0 import_ai4sh_csv (overwriting)
# Overwrite is set to True, all existing JSON files will be deleted before processing new data
# Directory removed: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh
# Directory removed: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_preservation__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_transport__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_storage__name>
#  ⚠️ WARNING - assuming default value <0> for  parameter <transport_duration_h>
#  ⚠️ WARNING - assuming default value <0> for  parameter <replicate>
#  ⚠️ WARNING - assuming default value <a> for  parameter <subsample>
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_4-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_4-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_5-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_5-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_16-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_16-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_20-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_20-a_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_51-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_51-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_55-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_55-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_60-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_60-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_61-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_61-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_72-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_72-c_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_79-d_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_79-d_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_ai4sh/se-loennstorp-20240815_80-d_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/infiltration/database_xspectre/se-loennstorp-20240815_80-d_0-20_a_0_uniform_no-prep_multiple_multiple_20240815.json
# ❌  ERROR - locus not found in coordinate_D: se-loennstorp_005-organic
#  To fix this problem make sure to add the locus to the file:
#  /users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/ai4sh_point_name_position_sampledate_all.csv
# Done

# %% [markdown]
# ## Import eDNA

# %%
process_file = 'eDNA/doc/json/process_eDNA_ai4sh.json'

Initiate_process(user_project_file, process_file)

# %% [markdown]
# ## Import aggregate stability

# %%
process_file = 'aggregates/doc/json/process_aggregates_ai4sh.json'

Initiate_process(user_project_file, process_file)
