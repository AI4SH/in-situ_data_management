# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library for running the Notebook.

# %%
# Standard library imports
from os import path

import sys

# Set the path to the root directory of this project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package import
from src.lib import Initiate_process
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 14
#      11     sys.path.append(module_path)
#      13 # Package import
# ---> 14 from src.lib import Initiate_process
#
# File ~/GitHub_AI4SH/in-situ_data_management/src/lib/__init__.py:21
#      17 from .spectra_2_OSSL import Interpolate_spectra
#      19 from .fix_params_coords import Parameters_fix, Coordinates_fix, Data_read
# ---> 21 from .AI4SH_4_Ai4SH import Process_ai4sh_csv
#      23 from .xspectre_4_Ai4SH import Process_xspectre_json_v089
#      25 from .NeoSpectra_4_Ai4SH import Process_neospectra_csv
#
# ModuleNotFoundError: No module named 'src.lib.AI4SH_4_Ai4SH'

# %% [markdown]
# ## Import FOSS DS2500
#
# To run this cell you need to set:
# 1. A _project_definition_file_, and
# 2. a _job_file_, that is linked via the _project_definition_file_.

# %%
user_project_file = '~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json'

process_file = 'DS2500_spectra/doc/json/process_DS2500.json'


Initiate_process(user_project_file, process_file)
# Out:
# Initiating process with user project file: ~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json
# ====== Parameters from user project file:
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': [{'delete': False,
#               'overwrite': False,
#               'src_path': {'ext': 'json', 'volume': '.'},
#               'translate': True,
#               'verbose': 3}],
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
# ======
# ====== Parameters from project file:
# {'process': [{'overwrite': True,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/DK_AI4SH_DS_202507.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'DK',
#                              'pilot_site': 'Foulum',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20240913',
#                              'sample_date': '20241105',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/DK_AI4SH_MX_202508.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'DK',
#                              'pilot_site': 'Foulum',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20240901',
#                              'sample_preparation__name': 'mx',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/FI_AI4SH_202411.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'FI',
#                              'pilot_site': 'Jokioinen',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20241007',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'canopy': 'alley',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/HR_AI4SH_202411.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'HR',
#                              'pilot_site': 'Neretva',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20241012',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'canopy': 'uniform',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/NL_AI4SH_DS_202509.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'NL',
#                              'pilot_site': 'Boermarke-Zeijen',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20250901',
#                              'sample_date': '20250411',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': True,
#               'parameters': {'analysis_method__name': 'diffuse-reflectance-spectroscopy',
#                              'canopy': 'uniform',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/SE_AI4SH_202411.csv',
#                              'dst_FP': '/Users/thomasgumbricht/GitHub_AI4SH/in-situ_data/DS2500_spectra',
#                              'dst_FP_1': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument_brand__name': 'foss',
#                              'instrument_id': 'AU',
#                              'instrument_model__name': 'ds2500',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'SE',
#                              'pilot_site': 'Loennstorp',
#                              'point_name_position_sampledate_FPN': 'metadata/AI4SH_point_name_position_sampledate_all.csv',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20250901',
#                              'sample_date': '20240815',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': True}]}
# ======
#   Json process files:
#      /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/doc/json/process_DS2500.json
# ====== Default parameter dictionary:
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': {'delete': False,
#              'overwrite': False,
#              'src_path': {'ext': 'json', 'volume': '.'},
#              'translate': True,
#              'verbose': 3},
#  'process_path': '',
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
# ======
#
#     reading jsonObj:
#     /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/doc/json/process_DS2500.json
#
# ########### STARTING JOB ###########
#
# Command file:
#   process_DS2500.json (6 ready processes to run)
# Directory removed: /users/thomasgumbricht/github_ai4sh/in-situ_data/ds2500_spectra_ai4sh
# Directory removed: /users/thomasgumbricht/github_ai4sh/in-situ_data/ds2500_spectra_xspectre
#
#     Running process nr: 5 import_ds2500_csv (overwriting)
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_preservation__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_transport__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_storage__name>
#  ⚠️ WARNING - assuming default value <0> for  parameter <transport_duration_h>
#  ⚠️ WARNING - assuming default value <0> for  parameter <replicate>
#  ⚠️ WARNING - assuming default value <a> for  parameter <subsample>
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_2-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_2-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_4-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_4-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_4-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_4-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_5-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_5-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_16-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_16-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_16-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_16-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_20-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_20-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_20-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_20-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_24-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_24-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_24-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_24-a_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_51-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_51-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_51-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_51-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_55-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_55-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_55-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_55-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_60-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_60-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_60-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_60-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_61-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_61-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_61-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_61-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_72-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_72-c_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_72-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_72-c_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_79-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_79-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_79-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_79-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_80-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_80-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_91-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_91-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_91-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_91-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_95-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_95-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_99-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_99-d_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_1-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_1-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_1-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_1-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_2-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_2-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_3-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_3-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_3-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_3-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_4-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_4-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_4-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_4-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_5-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_5-organic_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_5-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_5-organic_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_9-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_9-sand_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_9-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_9-sand_20-50_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_5-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_5-a_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_80-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_80-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_95-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_95-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ ai4sh Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/ai4sh/ds2500_spectra/se-loennstorp-20240815_99-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# ✅ xspectre Json post created successfully: /users/thomasgumbricht/github_ai4sh/in-situ_data/xspectre/ds2500_spectra/se-loennstorp-20240815_99-d_0-20_a_0_uniform_dried-sieved_ds2500_au_20250901.json
# Done
