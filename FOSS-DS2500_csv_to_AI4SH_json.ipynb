# %% [markdown]
# ## Imports and setup
#
# The first cell creates a path to the notebook and imports the required library for running the Notebook.

# %%
# Standard library imports
from os import path

import sys

# Set the path to the root directory of this project
module_path = path.abspath(path.join('..'))

if module_path not in sys.path:
    
    sys.path.append(module_path)

# Package import
from src.lib import Initiate_process

# %% [markdown]
# ## Import FOSS DS2500
#
# To run this cell you need to set:
# 1. A _project_definition_file_, and
# 2. a _job_file_, that is linked via the _project_definition_file_.

# %%
user_project_file = '~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json'

process_file = 'DS2500_spectra/doc/json/process_DS2500.json'


Initiate_process(user_project_file, process_file)
# Out:
# Initiating process with user project file: ~/projects/ai4sh_sueloanalys/project_file_ai4sh_sueloanalys.json
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': [{'delete': False,
#               'overwrite': False,
#               'src_path': {'ext': 'json', 'volume': '.'},
#               'translate': True,
#               'verbose': 3}],
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
# ====== Parameters from project file:
# {'process': [{'overwrite': True,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'coordinates_FPN_missing': True,
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/DK_AI4SH_DS_202507.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'DK',
#                              'pilot_site': 'Foulum',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20240913',
#                              'sample_date': '20241105',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'coordinates_FPN_missing': True,
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/DK_AI4SH_MX_202508.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'DK',
#                              'pilot_site': 'Foulum',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20240901',
#                              'sample_preparation__name': 'mx',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'coordinates_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_coordination '
#                                                 'points_tg.csv',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/FI_AI4SH_202411.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'FI',
#                              'pilot_site': 'Jokioinen',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20241007',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': False},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'canopy': 'alley',
#                              'coordinates_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_coordination '
#                                                 'points_tg.csv',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/HR_AI4SH_202411.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'HR',
#                              'pilot_site': 'Neretva',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20241113',
#                              'sample_date': '20241012',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': True},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'canopy': 'uniform',
#                              'coordinates_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_coordination '
#                                                 'points_tg.csv',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/NL_AI4SH_DS_202509.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'NL',
#                              'pilot_site': 'Boermarke-Zeijen',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20250901',
#                              'sample_date': '20250411',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': True},
#              {'overwrite': False,
#               'parameters': {'analysis_method__name': 'diffuse spectral '
#                                                       'spectroscopy',
#                              'canopy': 'uniform',
#                              'coordinates_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/coordinates/AI4SH_coordination '
#                                                 'points_tg.csv',
#                              'data_src_FPN': '/Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/data/SE_AI4SH_202411.csv',
#                              'dst_FP': 'DS2500_spectra/database',
#                              'indicator__name': 'reflectance',
#                              'instrument-brand__name': 'foss',
#                              'instrument-model__name': 'ds2500',
#                              'instrument_id': 'AU',
#                              'method': 'spectroscopy',
#                              'method_src_FPN': 'header_dictionary/header_dictionary_foss-ds2500.csv',
#                              'pilot_country': 'SE',
#                              'pilot_site': 'Loennstorp',
#                              'procedure': 'foss-ds2500-scan',
#                              'sample_analysis_date': '20250901',
#                              'sample_date': '20240815',
#                              'sample_preparation__name': 'ds',
#                              'unit__name': 'reflectance',
#                              'user_analysis__email': 'analysis@gmail.com',
#                              'user_logistic__email': 'logistic@gmail.com',
#                              'user_sampling__email': 'sampling@gmail.com'},
#               'sub_process_id': 'import_ds2500_csv',
#               'translate': True}]}
# ======
#   Json process files:
#      /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/doc/json/process_DS2500.json
#     default_parameter_D:
# {'postgresdb': {'db': None, 'host': None, 'host_netrc_id': None},
#  'process': {'delete': False,
#              'overwrite': False,
#              'src_path': {'ext': 'json', 'volume': '.'},
#              'translate': True,
#              'verbose': 3},
#  'process_path': '',
#  'project_path': '~/projects/ai4sh_sueloanalys',
#  'userproject': {'user_netrc_id': 'thomasg_xspectre',
#                  'user_pswd': '',
#                  'userid': 'thomasg'}}
#
#     reading jsonObj:
#     /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/doc/json/process_DS2500.json
#
# ########### STARTING JOB ###########
#
# Command file:
#   process_DS2500.json (6 ready processes to run)
#
#     Running process nr: 3 import_ds2500_csv
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_preservation__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_transport__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_storage__name>
#  ⚠️ WARNING - assuming default value <0> for  parameter <transport_duration_h>
#  ⚠️ WARNING - assuming default value <0> for  parameter <replicate>
#  ⚠️ WARNING - assuming default value <a> for  parameter <subsample>
# R_9_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_9-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_9-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_9_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_9-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_9-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_2_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_2-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_2-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_2_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_2-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_2-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_1_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_1-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_1-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_1_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_1-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_1-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_11_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_11-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_11-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_11_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_11-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_11-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_3_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_3-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_3-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_3_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_3-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_3-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_4_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_4-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_4-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_4_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_4-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_4-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_8_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_8-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_8-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_8_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_8-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_8-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_12_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_12-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_12-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_12_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_12-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_12-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_5_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_5-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_5-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_5_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_5-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_5-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_6_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_6-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_6-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_6_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_6-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_6-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_7_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_7-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_7-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_7_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_7-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_7-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_10_0-20_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_10-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_10-r_0-20_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# R_10_20-50_HR
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/hr-neretva-20241012_10-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/hr-neretva-20241012_10-r_20-50_a_0_alley_dried-sieved_ds2500_AU_20241113.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
#
#     Running process nr: 4 import_ds2500_csv
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_preservation__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_transport__name>
#  ⚠️ WARNING - assuming default value <None> for  parameter <sample_storage__name>
#  ⚠️ WARNING - assuming default value <0> for  parameter <transport_duration_h>
#  ⚠️ WARNING - assuming default value <0> for  parameter <replicate>
#  ⚠️ WARNING - assuming default value <a> for  parameter <subsample>
# NL_01_top_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_top_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_top_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_sub_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_sub_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_sub_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_top_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_top_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_top_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_sub_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_sub_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_01_extra_sub_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_1-extra_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_1-extra_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_top_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_top_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_top_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_sub_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_sub_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_02_sub_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_2_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_2_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_top_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_top_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_top_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_sub_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_sub_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_03_sub_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_3_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_3_20-50_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_04_top_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_4_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_4_0-20_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_04_top_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_4_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_4_0-20_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_04_top_DS_3
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_4_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_4_0-20_a_3_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_04_sub_DS_1
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_4_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_4_20-50_a_1_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# NL_04_sub_DS_2
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/nl-boermarke-zeijen-20250411_4_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/nl-boermarke-zeijen-20250411_4_20-50_a_2_uniform_dried-sieved_ds2500_AU_20250901.json
# ...
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_72-c_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_72-c_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_72-c_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_72-c_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_79-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_79-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_79-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_79-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_80-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_80-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_91-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_91-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_91-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_91-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_95-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_95-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_99-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_99-d_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_1-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_1-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_1-sand_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_1-sand_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_2-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_2-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_3-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_3-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_3-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_3-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_4-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_4-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_4-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_4-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_5-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_5-organic_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_5-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_5-organic_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_9-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_9-sand_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_9-sand_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_9-sand_20-50_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_5-a_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_5-a_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_80-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_80-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_95-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_95-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# ✅ ai4sh Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_ai4sh/se-loennstorp-20240815_99-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# ✅ xspectre Json post created successfully: /Users/thomasgumbricht/projects/ai4sh_sueloanalys/DS2500_spectra/database_xspectre/se-loennstorp-20240815_99-d_0-20_a_0_uniform_dried-sieved_ds2500_AU_20250901.json
# AI4SH_Key_L ['pilot_site', 'point_id', 'depth', 'sample_id', 'sample_preparation__name', 'subsample', 'replicate', 'instrument-model__name', 'instrument_id', 'instrument_setting', 'sample_analysis_date', 'license', 'doi', 'user_analysis__email']
# Done
